# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
print("My name is Kaustav")
# Out:
# My name is Kaustav

# %%
10 + 25
# Out:
# 35

# %%
print(8-5)
# Out:
# 3

# %%
print('8-5')
# Out:
# 8-5

# %%
print('2.3')
# Out:
# 2.3
