# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
print("My name is Kaustav")
# Out:
# My name is Kaustav

# %%
10 + 25
# Out:
# 35

# %%
print(8-5)
# Out:
# 3

# %%
print('8-5')
# Out:
# 8-5

# %%
print('2.3')
# Out:
# 2.3

# %%
print(type("kaustubh"))
# Out:
# <class 'str'>

# %%
a=kaustubh
print("a")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a=kaustubh
#       2 print("a")
#
# NameError: name 'kaustubh' is not defined
