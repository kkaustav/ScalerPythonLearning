# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
print("My name is Kaustav")
# Out:
# My name is Kaustav

# %%
10 + 25
# Out:
# 35

# %%
print(8-5)
# Out:
# 3

# %%
print('8-5')
# Out:
# 8-5

# %%
print('2.3')
# Out:
# 2.3

# %%
print(type("kaustubh"))
# Out:
# <class 'str'>

# %%
a="kaustubh"
print(a)
# Out:
# kaustubh

# %%
name=input()
print("Have a good day",name,type(name))
# Out:
# Have a good day kaustubh <class 'str'>

# %%
x=3
y='hello'
num = y
y=5
print(num,y)
# Out:
# hello 5

# %%
a='kaustubh'
print("hello", a)
# Out:
# hello kaustubh

# %%
a=int(input())
b=int(input())
print(a + b)
# Out:
# 24

# %%
## Addition

8+2
# Out:
# 10

# %%
## Subtraction
8-2
# Out:
# 6

# %%
## Division
10/3
# Out:
# 3.3333333333333335

# %%
5.0 + 5   ## Float + Integer ----> Float
# Out:
# 10.0

# %%
8 * 2.0
# Out:
# 16.0

# %%
10/5
# Out:
# 2.0

# %%
x=10
y=2.5
print(x/y)
# Out:
# 4.0

# %%
## Exponent
2*2*2
# Out:
# 8

# %%
2**3
# Out:
# 8

# %%
0.1**10
# Out:
# 1.0000000000000006e-10

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
-10//3
# Out:
# -4

# %%
-10//2.5
# Out:
# -4.0

# %%
27//5.0
# Out:
# 5.0

# %%
29//5.0
# Out:
# 5.0

# %%
20//0.7
# Out:
# 28.0

# %%
15//2
# Out:
# 7

# %%
10 % 2.3
# Out:
# 0.8000000000000007

# %%
10 % 2
# Out:
# 0

# %%
10 % 3
# Out:
# 1

# %%
-10 % 3
# Out:
# 2

# %%
"hello"=="heLlo" ## case-sensitive so false
# Out:
# False

# %%
x=5
x=x+2
x
# Out:
# 7

# %%
marks=50
correction=0.5
marks=marks+correction
marks=marks+correction
marks
# Out:
# 51.0

# %%
a=5
a+=2
print(a)
# Out:
# 7

# %%
Decimal('0.1')**10
# Out:
# Decimal('1E-10')

# %%
a="kaustubh"
print(a)
# Out:
# kaustubh

# %%
marks=55
correction=0.8
marks=marks+correction
marks=marks+correction
marks
# Out:
# 56.599999999999994

# %%
a=input()
b=input()
c=input()
print(a + b + c)
# Out:
# Hello Kaustubh!

# %%
-10//2.5
# Out:
# -4.0

# %%
27//5.0
# Out:
# 5.0

# %%
0.3**10
# Out:
# 5.9048999999999975e-06

# %%
0.2**10
# Out:
# 1.0240000000000006e-07

# %%
15.7//1.57
# Out:
# 9.0

# %%
10 % 3
# Out:
# 1

# %%
10 % 2
# Out:
# 0

# %%
10 % 2.3  ## a % b = a - (a//b)*b
# Out:
# 0.8000000000000007

# %%
10 // 2.3
# Out:
# 4.0

# %%
4.0 * 2.3
# Out:
# 9.2

# %%
10 - 9.2
# Out:
# 0.8000000000000007

# %%
-10 % 3
# Out:
# 2

# %%
10 % 3
# Out:
# 1

# %%
10 % 4
# Out:
# 2

# %%
10 % 5
# Out:
# 0

# %%
10 - (10//4)*4
# Out:
# 2

# %%
A = int(input())
B = int(input())
print(max(A, B))
# Out:
# 6

# %%
A=float(input())
B=int(input())
print(int(A // B))
# Out:
# 3

# %%
A=float(input())
B=int(input())
print(A // B)
# Out:
# 3.0

# %%
A=int(input())
B=int(input())
C=int(input())
print(1 if A + B + C == 180 else 0)
# Out:
# 1

# %%
x = 2
if x==2:
    x = 3
x = 4
else:
    x = 5
print(x)
# Out:
#   File "/tmp/ipykernel_1817/3068663205.py", line 5
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
x = 2
if x==2:
    x = 3
else:
    x = 5
print(x)
# Out:
# 3

# %%
print(True == 1)
# Out:
# True

# %%
print("1" == 1)
# Out:
# False

# %%
x = 55 / 11
print(x)
# Out:
# 5.0

# %%
x = 55 / 11
print(int(x))
# Out:
# 5

# %%
x = int(55 / 11)
print(x)
# Out:
# 5

# %%
x = 55 / 12
print(int(x))
# Out:
# 4

# %%
x = 55 / 12
print(x)
# Out:
# 4.583333333333333

# %%
C=int(input())
S=int(input())
if S > C:
    print(1)
    print(S - C)
else:
    print(-1)
    print(C - S)
# Out:
# 1
# 2

# %%
(3 + 4) // 2 + 6
# Out:
# 9

# %%
print("54" + "23")
# Out:
# 5423

# %%
x = int(input())
a = "You can ride the roller coaster!"
b= "You can't ride the roller coaster."
print(a if  x >= 13 else b)
# Out:
# You can't ride the roller coaster.

# %%
x = int(input())
print(True if x < 1234880990 else False)
# Out:
# False

# %%
x = int(input())
print(x < 1234880990)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
A=50
b=90
a==b
# Out:
# False

# %%
100==100.0
# Out:
# True

# %%
35 % 2
# Out:
# 1

# %%
## New Line
print("1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.\n2. Knead the dough for 10 minutes.\n3. Add 3g of Salt.\n4. Leave to rise for 2 hours.\n5. Bake at 200 degrees C for 30 minutes.")
# Out:
# 1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
# 2. Knead the dough for 10 minutes.
# 3. Add 3g of Salt.
# 4. Leave to rise for 2 hours.
# 5. Bake at 200 degrees C for 30 minutes.

# %%
## concatination
