# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
print("My name is Kaustav")
# Out:
# My name is Kaustav

# %%
10 + 25
# Out:
# 35

# %%
print(8-5)
# Out:
# 3

# %%
print('8-5')
# Out:
# 8-5

# %%
print('2.3')
# Out:
# 2.3

# %%
print(type("kaustubh"))
# Out:
# <class 'str'>

# %%
a="kaustubh"
print(a)
# Out:
# kaustubh

# %%
name=input()
print("Have a good day",name,type(name))
# Out:
# Have a good day kaustubh <class 'str'>

# %%
x=3
y='hello'
num = y
y=5
print(num,y)
# Out:
# hello 5

# %%
a='kaustubh'
print("hello", a)
# Out:
# hello kaustubh

# %%
a=int(input())
b=int(input())
print(a + b)
# Out:
# 24

# %%
## Addition

8+2
# Out:
# 10

# %%
## Subtraction
8-2
# Out:
# 6

# %%
## Division
10/3
# Out:
# 3.3333333333333335

# %%
5.0 + 5   ## Float + Integer ----> Float
# Out:
# 10.0

# %%
8 * 2.0
# Out:
# 16.0

# %%
10/5
# Out:
# 2.0

# %%
x=10
y=2.5
print(x/y)
# Out:
# 4.0

# %%
## Exponent
2*2*2
# Out:
# 8

# %%
2**3
# Out:
# 8

# %%
0.1**10
# Out:
# 1.0000000000000006e-10

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
-10//3
# Out:
# -4

# %%
-10//2.5
# Out:
# -4.0

# %%
27//5.0
# Out:
# 5.0

# %%
29//5.0
# Out:
# 5.0

# %%
20//0.7
# Out:
# 28.0

# %%
15//2
# Out:
# 7

# %%
10 % 2.3
# Out:
# 0.8000000000000007

# %%
10 % 2
# Out:
# 0

# %%
10 % 3
# Out:
# 1

# %%
-10 % 3
# Out:
# 2
