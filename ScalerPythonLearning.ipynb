# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
print("My name is Kaustav")
# Out:
# My name is Kaustav

# %%
10 + 25
# Out:
# 35

# %%
print(8-5)
# Out:
# 3

# %%
print('8-5')
# Out:
# 8-5

# %%
print('2.3')
# Out:
# 2.3

# %%
print(type("kaustubh"))
# Out:
# <class 'str'>

# %%
a="kaustubh"
print(a)
# Out:
# kaustubh

# %%
name=input()
print("Have a good day",name,type(name))
# Out:
# Have a good day kaustubh <class 'str'>

# %%
x=3
y='hello'
num = y
y=5
print(num,y)
# Out:
# hello 5

# %%
a='kaustubh'
print("hello", a)
# Out:
# hello kaustubh

# %%
a=int(input())
b=int(input())
print(a + b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a=int(input())
#       2 b=int(input())
#       3 print(a + b)
#
# ValueError: invalid literal for int() with base 10: 'a=7\nb=3'
